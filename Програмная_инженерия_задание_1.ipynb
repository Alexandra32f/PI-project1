# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexandra32f/PI-project1/blob/annabogach86-patch-1/%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BD%D0%B0%D1%8F_%D0%B8%D0%BD%D0%B6%D0%B5%D0%BD%D0%B5%D1%80%D0%B8%D1%8F_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
question_answerer = pipeline("question-answering", model='distilbert-base-uncased-distilled-squad')

# %%
context = r"""
The Universe contains everything that exists – not only the Earth and everything on it,but also all the planets, stars,
and galaxies, and the space in between them. The sun, at the center of the solar system, is just one of about 100 billion stars
in our galaxy, or collection of stars, called the Milky Way. Astronomers have estimated that there are about 100 billion other
galaxies in the universe. Most scientists think that the universe formed about 15 billion years ago in an enormous explosion
called the big bang.They also think that the universe is expanding.
"""

# %%
result = question_answerer(question="What is at the center of the solar system?",     context=context)

print(f"Answer: '{result['answer']}'"
      f"score: {round(result['score'], 4)}"
      f"start: {result['start']}"
      f"end: {result['end']}")
# Out:
# Answer: 'The sun'score: 0.9084start: 167end: 174

# %%
result = question_answerer(question="How many stars are in our galaxy?",     context=context)

print(f"Answer: '{result['answer']}'"
      f"score: {round(result['score'], 4)}"
      f"start: {result['start']}"
      f"end: {result['end']}")
# Out:
# Answer: '100 billion'score: 0.7251start: 232end: 243

# %%
result = question_answerer(question="When did the universe begin?",     context=context)

print(f"Answer: '{result['answer']}'"
      f"score: {round(result['score'], 4)}"
      f"start: {result['start']}"
      f"end: {result['end']}")
# Out:
# Answer: '15 billion years ago'score: 0.713start: 458end: 478
